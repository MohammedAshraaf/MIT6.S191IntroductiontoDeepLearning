# %% [markdown]
# <table align="center">
#   <td align="center"><a target="_blank" href="http://introtodeeplearning.com">
#         <img src="http://introtodeeplearning.com/images/colab/mit.png" style="padding-bottom:5px;" />
#       Visit MIT Deep Learning</a></td>
#   <td align="center"><a target="_blank" href="https://colab.research.google.com/github/aamini/introtodeeplearning/blob/master/lab2/Part1_MNIST.ipynb">
#         <img src="http://introtodeeplearning.com/images/colab/colab.png?v2.0"  style="padding-bottom:5px;" />Run in Google Colab</a></td>
#   <td align="center"><a target="_blank" href="https://github.com/aamini/introtodeeplearning/blob/master/lab2/Part1_MNIST.ipynb">
#         <img src="http://introtodeeplearning.com/images/colab/github.png"  height="70px" style="padding-bottom:5px;"  />View Source on GitHub</a></td>
# </table>
#
# # Copyright Information

# %%
# Copyright 2020 MIT 6.S191 Introduction to Deep Learning. All Rights Reserved.
# 
# Licensed under the MIT License. You may not use this file except in compliance
# with the License. Use and/or modification of this code outside of 6.S191 must
# reference:
#
# © MIT 6.S191: Introduction to Deep Learning
# http://introtodeeplearning.com
#

# %% [markdown]
# # Laboratory 2: Computer Vision
#
# # Part 1: MNIST Digit Classification
#
# In the first portion of this lab, we will build and train a convolutional neural network (CNN) for classification of handwritten digits from the famous [MNIST](http://yann.lecun.com/exdb/mnist/) dataset. The MNIST dataset consists of 60,000 training images and 10,000 test images. Our classes are the digits 0-9.
#
# First, let's download the course repository, install dependencies, and import the relevant packages we'll need for this lab.

# %%
# Import Tensorflow 2.0
#%tensorflow_version 2.x
import tensorflow as tf 

# !pip install mitdeeplearning
import mitdeeplearning as mdl

import matplotlib.pyplot as plt
import numpy as np
import random
from tqdm import tqdm

# Check that we are using a GPU, if not switch runtimes
#   using Runtime > Change Runtime Type > GPU
assert len(tf.config.list_physical_devices('GPU')) > 0
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)
# Out:
# Requirement already satisfied: mitdeeplearning in c:\users\moham\anaconda3\lib\site-packages (0.1.2)
# Requirement already satisfied: numpy in c:\users\moham\anaconda3\lib\site-packages (from mitdeeplearning) (1.16.5)
# Requirement already satisfied: gym in c:\users\moham\anaconda3\lib\site-packages (from mitdeeplearning) (0.17.0)
# Requirement already satisfied: tqdm in c:\users\moham\anaconda3\lib\site-packages (from mitdeeplearning) (4.36.1)
# Requirement already satisfied: regex in c:\users\moham\anaconda3\lib\site-packages (from mitdeeplearning) (2020.2.20)
# Requirement already satisfied: scipy in c:\users\moham\anaconda3\lib\site-packages (from gym->mitdeeplearning) (1.3.1)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in c:\users\moham\anaconda3\lib\site-packages (from gym->mitdeeplearning) (1.5.0)
# Requirement already satisfied: six in c:\users\moham\anaconda3\lib\site-packages (from gym->mitdeeplearning) (1.12.0)
# Requirement already satisfied: cloudpickle~=1.3.0 in c:\users\moham\anaconda3\lib\site-packages (from gym->mitdeeplearning) (1.3.0)
# Requirement already satisfied: future in c:\users\moham\anaconda3\lib\site-packages (from pyglet<=1.5.0,>=1.4.0->gym->mitdeeplearning) (0.17.1)

# %% [markdown]
# ## 1.1 MNIST dataset
#
# Let's download and load the dataset and display a few random samples from it:

# %%
mnist = tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = (np.expand_dims(train_images, axis=-1)/255.).astype(np.float32)
train_labels = (train_labels).astype(np.int64)
test_images = (np.expand_dims(test_images, axis=-1)/255.).astype(np.float32)
test_labels = (test_labels).astype(np.int64)

# %% [markdown]
# Our training set is made up of 28x28 grayscale images of handwritten digits.
#
# Let's visualize what some of these images and their corresponding training labels look like.

# %%
plt.figure(figsize=(10,10))
random_inds = np.random.choice(60000,36)
for i in range(36):
    plt.subplot(6,6,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    image_ind = random_inds[i]
    plt.imshow(np.squeeze(train_images[image_ind]), cmap=plt.cm.binary)
    plt.xlabel(train_labels[image_ind])

# %% [markdown]
# ## 1.2 Neural Network for Handwritten Digit Classification
#
# We'll first build a simple neural network consisting of two fully connected layers and apply this to the digit classification task. Our network will ultimately output a probability distribution over the 10 digit classes (0-9). This first architecture we will be building is depicted below:
#
# ![alt_text](https://raw.githubusercontent.com/aamini/introtodeeplearning/master/lab2/img/mnist_2layers_arch.png "CNN Architecture for MNIST Classification")

# %% [markdown]
# ### Fully connected neural network architecture
# To define the architecture of this first fully connected neural network, we'll once again use the Keras API and define the model using the [`Sequential`](https://www.tensorflow.org/api_docs/python/tf/keras/models/Sequential) class. Note how we first use a [`Flatten`](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Flatten) layer, which flattens the input so that it can be fed into the model.
#
# In this next block, you'll define the fully connected layers of this simple work.

# %%
def build_fc_model():
  fc_model = tf.keras.Sequential([
      # First define a Flatten layer
      tf.keras.layers.Flatten(),

      # '''TODO: Define the activation function for the first fully connected (Dense) layer.'''
      tf.keras.layers.Dense(128, activation= 'relu'),

      # '''TODO: Define the second Dense layer to output the classification probabilities'''
      tf.keras.layers.Dense(10, activation= 'softmax'),
      
  ])
  return fc_model

model = build_fc_model()

# %% [markdown]
# As we progress through this next portion, you may find that you'll want to make changes to the architecture defined above. **Note that in order to update the model later on, you'll need to re-run the above cell to re-initialize the model. **

# %% [markdown]
# Let's take a step back and think about the network we've just created. The first layer in this network, `tf.keras.layers.Flatten`, transforms the format of the images from a 2d-array (28 x 28 pixels), to a 1d-array of 28 * 28 = 784 pixels. You can think of this layer as unstacking rows of pixels in the image and lining them up. There are no learned parameters in this layer; it only reformats the data.
#
# After the pixels are flattened, the network consists of a sequence of two `tf.keras.layers.Dense` layers. These are fully-connected neural layers. The first `Dense` layer has 128 nodes (or neurons). The second (and last) layer (which you've defined!) should return an array of probability scores that sum to 1. Each node contains a score that indicates the probability that the current image belongs to one of the handwritten digit classes.
#
# That defines our fully connected model!

# %% [markdown]
# ### Compile the model
#
# Before training the model, we need to define a few more settings. These are added during the model's [`compile`](https://www.tensorflow.org/api_docs/python/tf/keras/models/Sequential#compile) step:
#
# * *Loss function* — This defines how we measure how accurate the model is during training. As was covered in lecture, during training we want to minimize this function, which will "steer" the model in the right direction.
# * *Optimizer* — This defines how the model is updated based on the data it sees and its loss function.
# * *Metrics* — Here we can define metrics used to monitor the training and testing steps. In this example, we'll look at the *accuracy*, the fraction of the images that are correctly classified.
#
# We'll start out by using a stochastic gradient descent (SGD) optimizer initialized with a learning rate of 0.1. Since we are performing a categorical classification task, we'll want to use the [cross entropy loss](https://www.tensorflow.org/api_docs/python/tf/keras/metrics/sparse_categorical_crossentropy).
#
# You'll want to experiment with both the choice of optimizer and learning rate and evaluate how these affect the accuracy of the trained model.

# %%
'''TODO: Experiment with different optimizers and learning rates. How do these affect
    the accuracy of the trained model? Which optimizers and/or learning rates yield
    the best performance?'''
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=1e-1), 
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ### Train the model
#
# We're now ready to train our model, which will involve feeding the training data (`train_images` and `train_labels`) into the model, and then asking it to learn the associations between images and labels. We'll also need to define the batch size and the number of epochs, or iterations over the MNIST dataset, to use during training.
#
# In Lab 1, we saw how we can use `GradientTape` to optimize losses and train models with stochastic gradient descent. After defining the model settings in the `compile` step, we can also accomplish training by calling the [`fit`](https://www.tensorflow.org/api_docs/python/tf/keras/models/Sequential#fit) method on an instance of the `Model` class. We will use this to train our fully connected model

# %%
# Define the batch size and the number of epochs to use during training
BATCH_SIZE = 64
EPOCHS = 5

model.fit(train_images, train_labels, batch_size=BATCH_SIZE, epochs=EPOCHS)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - ETA: 6:19 - loss: 2.3222 - accuracy: 0.14 - ETA: 11s - loss: 1.3773 - accuracy: 0.6402 - ETA: 5s - loss: 1.0229 - accuracy: 0.740 - ETA: 4s - loss: 0.8490 - accuracy: 0.78 - ETA: 3s - loss: 0.7445 - accuracy: 0.80 - ETA: 2s - loss: 0.6814 - accuracy: 0.82 - ETA: 2s - loss: 0.6349 - accuracy: 0.83 - ETA: 2s - loss: 0.5986 - accuracy: 0.84 - ETA: 1s - loss: 0.5685 - accuracy: 0.84 - ETA: 1s - loss: 0.5443 - accuracy: 0.85 - ETA: 1s - loss: 0.5212 - accuracy: 0.86 - ETA: 1s - loss: 0.5043 - accuracy: 0.86 - ETA: 1s - loss: 0.4867 - accuracy: 0.86 - ETA: 1s - loss: 0.4732 - accuracy: 0.87 - ETA: 0s - loss: 0.4610 - accuracy: 0.87 - ETA: 0s - loss: 0.4491 - accuracy: 0.87 - ETA: 0s - loss: 0.4375 - accuracy: 0.88 - ETA: 0s - loss: 0.4288 - accuracy: 0.88 - ETA: 0s - loss: 0.4206 - accuracy: 0.88 - ETA: 0s - loss: 0.4134 - accuracy: 0.88 - ETA: 0s - loss: 0.4052 - accuracy: 0.88 - ETA: 0s - loss: 0.3980 - accuracy: 0.89 - ETA: 0s - loss: 0.3911 - accuracy: 0.89 - ETA: 0s - loss: 0.3863 - accuracy: 0.89 - ETA: 0s - loss: 0.3807 - accuracy: 0.89 - ETA: 0s - loss: 0.3759 - accuracy: 0.89 - ETA: 0s - loss: 0.3711 - accuracy: 0.89 - 2s 29us/sample - loss: 0.3704 - accuracy: 0.8969
# Epoch 2/5
# 60000/60000 [==============================] - ETA: 2s - loss: 0.2480 - accuracy: 0.92 - ETA: 1s - loss: 0.2330 - accuracy: 0.93 - ETA: 1s - loss: 0.2405 - accuracy: 0.93 - ETA: 1s - loss: 0.2317 - accuracy: 0.93 - ETA: 1s - loss: 0.2241 - accuracy: 0.93 - ETA: 1s - loss: 0.2263 - accuracy: 0.93 - ETA: 0s - loss: 0.2215 - accuracy: 0.93 - ETA: 0s - loss: 0.2181 - accuracy: 0.93 - ETA: 0s - loss: 0.2145 - accuracy: 0.93 - ETA: 0s - loss: 0.2142 - accuracy: 0.93 - ETA: 0s - loss: 0.2128 - accuracy: 0.93 - ETA: 0s - loss: 0.2127 - accuracy: 0.93 - ETA: 0s - loss: 0.2125 - accuracy: 0.93 - ETA: 0s - loss: 0.2122 - accuracy: 0.93 - ETA: 0s - loss: 0.2104 - accuracy: 0.94 - ETA: 0s - loss: 0.2103 - accuracy: 0.94 - ETA: 0s - loss: 0.2093 - accuracy: 0.94 - ETA: 0s - loss: 0.2077 - accuracy: 0.94 - ETA: 0s - loss: 0.2076 - accuracy: 0.94 - ETA: 0s - loss: 0.2063 - accuracy: 0.94 - ETA: 0s - loss: 0.2054 - accuracy: 0.94 - ETA: 0s - loss: 0.2037 - accuracy: 0.94 - ETA: 0s - loss: 0.2020 - accuracy: 0.94 - ETA: 0s - loss: 0.2018 - accuracy: 0.94 - ETA: 0s - loss: 0.2006 - accuracy: 0.94 - ETA: 0s - loss: 0.2001 - accuracy: 0.94 - ETA: 0s - loss: 0.1992 - accuracy: 0.94 - 1s 22us/sample - loss: 0.1989 - accuracy: 0.9432
# Epoch 3/5
# 60000/60000 [==============================] - ETA: 1s - loss: 0.1588 - accuracy: 0.95 - ETA: 1s - loss: 0.1744 - accuracy: 0.95 - ETA: 1s - loss: 0.1630 - accuracy: 0.95 - ETA: 1s - loss: 0.1610 - accuracy: 0.95 - ETA: 1s - loss: 0.1654 - accuracy: 0.95 - ETA: 1s - loss: 0.1645 - accuracy: 0.95 - ETA: 0s - loss: 0.1627 - accuracy: 0.95 - ETA: 0s - loss: 0.1640 - accuracy: 0.95 - ETA: 0s - loss: 0.1631 - accuracy: 0.95 - ETA: 0s - loss: 0.1615 - accuracy: 0.95 - ETA: 0s - loss: 0.1627 - accuracy: 0.95 - ETA: 0s - loss: 0.1615 - accuracy: 0.95 - ETA: 0s - loss: 0.1603 - accuracy: 0.95 - ETA: 0s - loss: 0.1598 - accuracy: 0.95 - ETA: 0s - loss: 0.1595 - accuracy: 0.95 - ETA: 0s - loss: 0.1583 - accuracy: 0.95 - ETA: 0s - loss: 0.1584 - accuracy: 0.95 - ETA: 0s - loss: 0.1560 - accuracy: 0.95 - ETA: 0s - loss: 0.1559 - accuracy: 0.95 - ETA: 0s - loss: 0.1564 - accuracy: 0.95 - ETA: 0s - loss: 0.1556 - accuracy: 0.95 - ETA: 0s - loss: 0.1538 - accuracy: 0.95 - ETA: 0s - loss: 0.1532 - accuracy: 0.95 - ETA: 0s - loss: 0.1522 - accuracy: 0.95 - ETA: 0s - loss: 0.1519 - accuracy: 0.95 - ETA: 0s - loss: 0.1515 - accuracy: 0.95 - 1s 22us/sample - loss: 0.1512 - accuracy: 0.9572
# Epoch 4/5
# 60000/60000 [==============================] - ETA: 1s - loss: 0.1131 - accuracy: 0.96 - ETA: 1s - loss: 0.1104 - accuracy: 0.96 - ETA: 1s - loss: 0.1161 - accuracy: 0.96 - ETA: 1s - loss: 0.1194 - accuracy: 0.96 - ETA: 1s - loss: 0.1222 - accuracy: 0.96 - ETA: 1s - loss: 0.1266 - accuracy: 0.96 - ETA: 1s - loss: 0.1293 - accuracy: 0.96 - ETA: 0s - loss: 0.1277 - accuracy: 0.96 - ETA: 0s - loss: 0.1273 - accuracy: 0.96 - ETA: 0s - loss: 0.1278 - accuracy: 0.96 - ETA: 0s - loss: 0.1277 - accuracy: 0.96 - ETA: 0s - loss: 0.1267 - accuracy: 0.96 - ETA: 0s - loss: 0.1254 - accuracy: 0.96 - ETA: 0s - loss: 0.1256 - accuracy: 0.96 - ETA: 0s - loss: 0.1252 - accuracy: 0.96 - ETA: 0s - loss: 0.1272 - accuracy: 0.96 - ETA: 0s - loss: 0.1270 - accuracy: 0.96 - ETA: 0s - loss: 0.1265 - accuracy: 0.96 - ETA: 0s - loss: 0.1262 - accuracy: 0.96 - ETA: 0s - loss: 0.1261 - accuracy: 0.96 - ETA: 0s - loss: 0.1261 - accuracy: 0.96 - ETA: 0s - loss: 0.1252 - accuracy: 0.96 - ETA: 0s - loss: 0.1250 - accuracy: 0.96 - ETA: 0s - loss: 0.1242 - accuracy: 0.96 - ETA: 0s - loss: 0.1237 - accuracy: 0.96 - ETA: 0s - loss: 0.1234 - accuracy: 0.96 - ETA: 0s - loss: 0.1230 - accuracy: 0.96 - 1s 22us/sample - loss: 0.1231 - accuracy: 0.9646
# Epoch 5/5
# 60000/60000 [==============================] - ETA: 2s - loss: 0.0629 - accuracy: 0.98 - ETA: 1s - loss: 0.1040 - accuracy: 0.96 - ETA: 1s - loss: 0.0993 - accuracy: 0.97 - ETA: 1s - loss: 0.0977 - accuracy: 0.97 - ETA: 1s - loss: 0.1015 - accuracy: 0.97 - ETA: 1s - loss: 0.1039 - accuracy: 0.97 - ETA: 1s - loss: 0.1001 - accuracy: 0.97 - ETA: 0s - loss: 0.1031 - accuracy: 0.97 - ETA: 0s - loss: 0.1056 - accuracy: 0.97 - ETA: 0s - loss: 0.1042 - accuracy: 0.97 - ETA: 0s - loss: 0.1059 - accuracy: 0.96 - ETA: 0s - loss: 0.1072 - accuracy: 0.96 - ETA: 0s - loss: 0.1066 - accuracy: 0.96 - ETA: 0s - loss: 0.1068 - accuracy: 0.96 - ETA: 0s - loss: 0.1057 - accuracy: 0.96 - ETA: 0s - loss: 0.1053 - accuracy: 0.97 - ETA: 0s - loss: 0.1056 - accuracy: 0.97 - ETA: 0s - loss: 0.1060 - accuracy: 0.96 - ETA: 0s - loss: 0.1070 - accuracy: 0.96 - ETA: 0s - loss: 0.1061 - accuracy: 0.96 - ETA: 0s - loss: 0.1055 - accuracy: 0.96 - ETA: 0s - loss: 0.1060 - accuracy: 0.96 - ETA: 0s - loss: 0.1061 - accuracy: 0.96 - ETA: 0s - loss: 0.1056 - accuracy: 0.96 - ETA: 0s - loss: 0.1051 - accuracy: 0.96 - ETA: 0s - loss: 0.1047 - accuracy: 0.96 - ETA: 0s - loss: 0.1040 - accuracy: 0.97 - 1s 22us/sample - loss: 0.1040 - accuracy: 0.9700

# %% [markdown]
# As the model trains, the loss and accuracy metrics are displayed. With five epochs and a learning rate of 0.01, this fully connected model should achieve an accuracy of approximatley 0.97 (or 97%) on the training data.

# %% [markdown]
# ### Evaluate accuracy on the test dataset
#
# Now that we've trained the model, we can ask it to make predictions about a test set that it hasn't seen before. In this example, the `test_images` array comprises our test dataset. To evaluate accuracy, we can check to see if the model's predictions match the labels from the `test_labels` array.
#
# Use the [`evaluate`](https://www.tensorflow.org/api_docs/python/tf/keras/models/Sequential#evaluate) method to evaluate the model on the test dataset!

# %%
'''TODO: Use the evaluate method to test the model!'''
test_loss, test_acc = model.evaluate(
    x=test_images, y=test_labels
)

print('Test accuracy:', test_acc)
# Out:
# 10000/10000 [==============================] - ETA: 18s - loss: 0.0323 - accuracy: 0.968 - ETA: 0s - loss: 0.1214 - accuracy: 0.965 - ETA: 0s - loss: 0.1388 - accuracy: 0.96 - ETA: 0s - loss: 0.1370 - accuracy: 0.95 - ETA: 0s - loss: 0.1275 - accuracy: 0.96 - ETA: 0s - loss: 0.1198 - accuracy: 0.96 - ETA: 0s - loss: 0.1091 - accuracy: 0.96 - ETA: 0s - loss: 0.1041 - accuracy: 0.96 - 0s 42us/sample - loss: 0.1045 - accuracy: 0.9687
# Test accuracy: 0.9687

# %%
print(test_acc)
# Out:
# 0.9687

# %% [markdown]
# You may observe that the accuracy on the test dataset is a little lower than the accuracy on the training dataset. This gap between training accuracy and test accuracy is an example of *overfitting*, when a machine learning model performs worse on new data than on its training data.
#
# What is the highest accuracy you can achieve with this first fully connected model? Since the handwritten digit classification task is pretty straightforward, you may be wondering how we can do better...
#
# ![Deeper...](https://i.kym-cdn.com/photos/images/newsfeed/000/534/153/f87.jpg)

# %% [markdown]
# ## 1.3 Convolutional Neural Network (CNN) for handwritten digit classification

# %% [markdown]
# As we saw in lecture, convolutional neural networks (CNNs) are particularly well-suited for a variety of tasks in computer vision, and have achieved near-perfect accuracies on the MNIST dataset. We will now build a CNN composed of two convolutional layers and pooling layers, followed by two fully connected layers, and ultimately output a probability distribution over the 10 digit classes (0-9). The CNN we will be building is depicted below:
#
# ![alt_text](https://raw.githubusercontent.com/aamini/introtodeeplearning/master/lab2/img/convnet_fig.png "CNN Architecture for MNIST Classification")

# %% [markdown]
# ### Define the CNN model
#
# We'll use the same training and test datasets as before, and proceed similarly as our fully connected network to define and train our new CNN model. To do this we will explore two layers we have not encountered before: you can use  [`keras.layers.Conv2D` ](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D) to define convolutional layers and [`keras.layers.MaxPool2D`](https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D) to define the pooling layers. Use the parameters shown in the network architecture above to define these layers and build the CNN model.

# %%
def build_cnn_model():
    cnn_model = tf.keras.Sequential([

        # TODO: Define the first convolutional layer
        tf.keras.layers.Conv2D(filters=24, kernel_size=(3,3), activation=tf.nn.relu),
        # tf.keras.layers.Conv2D('''TODO''') 

        # TODO: Define the first max pooling layer
        tf.keras.layers.MaxPool2D(pool_size=(2,2)),
        # tf.keras.layers.MaxPool2D('''TODO''')

        # TODO: Define the second convolutional layer
        tf.keras.layers.Conv2D(filters=36, kernel_size=(3,3), activation=tf.nn.relu),
        # tf.keras.layers.Conv2D('''TODO''')

        # TODO: Define the second max pooling layer
        tf.keras.layers.MaxPool2D(pool_size=(2,2)),
        # tf.keras.layers.MaxPool2D('''TODO''')

        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation=tf.nn.relu),

        # TODO: Define the last Dense layer to output the classification 
        # probabilities. Pay attention to the activation needed a probability
        # output
        tf.keras.layers.Dense(10, activation=tf.nn.softmax)
        # [TODO Dense layer to output classification probabilities]
    ])
    
    return cnn_model
  
cnn_model = build_cnn_model()
# Initialize the model by passing some data through
cnn_model.predict(train_images[[0]])
# Print the summary of the layers in the model.
print(cnn_model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              multiple                  240
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) multiple                  0
# _________________________________________________________________
# conv2d_1 (Conv2D)            multiple                  7812
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 multiple                  0
# _________________________________________________________________
# flatten_1 (Flatten)          multiple                  0
# _________________________________________________________________
# dense_2 (Dense)              multiple                  115328
# _________________________________________________________________
# dense_3 (Dense)              multiple                  1290
# =================================================================
# Total params: 124,670
# Trainable params: 124,670
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Train and test the CNN model
#
# Now, as before, we can define the loss function, optimizer, and metrics through the `compile` method. Compile the CNN model with an optimizer and learning rate of choice:

# %%
'''TODO: Define the compile operation with your optimizer and learning rate of choice'''
cnn_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-2), loss='sparse_categorical_crossentropy', metrics=['accuracy']) # TODO

# %% [markdown]
# As was the case with the fully connected model, we can train our CNN using the `fit` method via the Keras API.

# %%
'''TODO: Use model.fit to train the CNN model, with the same batch_size and number of epochs previously used.'''
cnn_model.fit(train_images, train_labels, batch_size=BATCH_SIZE, epochs=EPOCHS)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - ETA: 5:44 - loss: 2.3098 - accuracy: 0.06 - ETA: 15s - loss: 1.2971 - accuracy: 0.5781 - ETA: 8s - loss: 0.8231 - accuracy: 0.737 - ETA: 6s - loss: 0.6247 - accuracy: 0.80 - ETA: 4s - loss: 0.5108 - accuracy: 0.83 - ETA: 4s - loss: 0.4383 - accuracy: 0.86 - ETA: 3s - loss: 0.3856 - accuracy: 0.87 - ETA: 3s - loss: 0.3509 - accuracy: 0.88 - ETA: 3s - loss: 0.3262 - accuracy: 0.89 - ETA: 2s - loss: 0.3049 - accuracy: 0.90 - ETA: 2s - loss: 0.2855 - accuracy: 0.90 - ETA: 2s - loss: 0.2682 - accuracy: 0.91 - ETA: 2s - loss: 0.2571 - accuracy: 0.91 - ETA: 2s - loss: 0.2463 - accuracy: 0.92 - ETA: 1s - loss: 0.2350 - accuracy: 0.92 - ETA: 1s - loss: 0.2258 - accuracy: 0.92 - ETA: 1s - loss: 0.2193 - accuracy: 0.93 - ETA: 1s - loss: 0.2129 - accuracy: 0.93 - ETA: 1s - loss: 0.2064 - accuracy: 0.93 - ETA: 1s - loss: 0.2019 - accuracy: 0.93 - ETA: 1s - loss: 0.1955 - accuracy: 0.93 - ETA: 1s - loss: 0.1908 - accuracy: 0.94 - ETA: 1s - loss: 0.1860 - accuracy: 0.94 - ETA: 1s - loss: 0.1818 - accuracy: 0.94 - ETA: 1s - loss: 0.1770 - accuracy: 0.94 - ETA: 0s - loss: 0.1734 - accuracy: 0.94 - ETA: 0s - loss: 0.1680 - accuracy: 0.94 - ETA: 0s - loss: 0.1646 - accuracy: 0.94 - ETA: 0s - loss: 0.1612 - accuracy: 0.94 - ETA: 0s - loss: 0.1578 - accuracy: 0.95 - ETA: 0s - loss: 0.1549 - accuracy: 0.95 - ETA: 0s - loss: 0.1525 - accuracy: 0.95 - ETA: 0s - loss: 0.1508 - accuracy: 0.95 - ETA: 0s - loss: 0.1482 - accuracy: 0.95 - ETA: 0s - loss: 0.1458 - accuracy: 0.95 - ETA: 0s - loss: 0.1438 - accuracy: 0.95 - ETA: 0s - loss: 0.1417 - accuracy: 0.95 - ETA: 0s - loss: 0.1397 - accuracy: 0.95 - ETA: 0s - loss: 0.1381 - accuracy: 0.95 - ETA: 0s - loss: 0.1369 - accuracy: 0.95 - 2s 41us/sample - loss: 0.1354 - accuracy: 0.9574
# Epoch 2/5
# 60000/60000 [==============================] - ETA: 3s - loss: 0.0143 - accuracy: 1.00 - ETA: 2s - loss: 0.0598 - accuracy: 0.98 - ETA: 1s - loss: 0.0530 - accuracy: 0.98 - ETA: 1s - loss: 0.0579 - accuracy: 0.98 - ETA: 1s - loss: 0.0574 - accuracy: 0.98 - ETA: 1s - loss: 0.0601 - accuracy: 0.98 - ETA: 1s - loss: 0.0628 - accuracy: 0.97 - ETA: 1s - loss: 0.0632 - accuracy: 0.97 - ETA: 1s - loss: 0.0654 - accuracy: 0.97 - ETA: 1s - loss: 0.0653 - accuracy: 0.97 - ETA: 1s - loss: 0.0664 - accuracy: 0.97 - ETA: 1s - loss: 0.0678 - accuracy: 0.97 - ETA: 1s - loss: 0.0675 - accuracy: 0.97 - ETA: 1s - loss: 0.0680 - accuracy: 0.97 - ETA: 1s - loss: 0.0686 - accuracy: 0.97 - ETA: 1s - loss: 0.0691 - accuracy: 0.97 - ETA: 1s - loss: 0.0683 - accuracy: 0.97 - ETA: 1s - loss: 0.0671 - accuracy: 0.97 - ETA: 1s - loss: 0.0670 - accuracy: 0.97 - ETA: 1s - loss: 0.0678 - accuracy: 0.97 - ETA: 1s - loss: 0.0669 - accuracy: 0.97 - ETA: 0s - loss: 0.0661 - accuracy: 0.97 - ETA: 0s - loss: 0.0658 - accuracy: 0.97 - ETA: 0s - loss: 0.0662 - accuracy: 0.97 - ETA: 0s - loss: 0.0661 - accuracy: 0.97 - ETA: 0s - loss: 0.0650 - accuracy: 0.97 - ETA: 0s - loss: 0.0656 - accuracy: 0.97 - ETA: 0s - loss: 0.0647 - accuracy: 0.98 - ETA: 0s - loss: 0.0641 - accuracy: 0.98 - ETA: 0s - loss: 0.0642 - accuracy: 0.98 - ETA: 0s - loss: 0.0648 - accuracy: 0.98 - ETA: 0s - loss: 0.0659 - accuracy: 0.97 - ETA: 0s - loss: 0.0655 - accuracy: 0.97 - ETA: 0s - loss: 0.0658 - accuracy: 0.97 - ETA: 0s - loss: 0.0656 - accuracy: 0.97 - ETA: 0s - loss: 0.0655 - accuracy: 0.98 - ETA: 0s - loss: 0.0649 - accuracy: 0.98 - ETA: 0s - loss: 0.0643 - accuracy: 0.98 - ETA: 0s - loss: 0.0639 - accuracy: 0.98 - ETA: 0s - loss: 0.0638 - accuracy: 0.98 - 2s 34us/sample - loss: 0.0638 - accuracy: 0.9807
# Epoch 3/5
# 60000/60000 [==============================] - ETA: 2s - loss: 0.0316 - accuracy: 1.00 - ETA: 1s - loss: 0.0574 - accuracy: 0.98 - ETA: 1s - loss: 0.0539 - accuracy: 0.98 - ETA: 1s - loss: 0.0466 - accuracy: 0.98 - ETA: 1s - loss: 0.0447 - accuracy: 0.98 - ETA: 1s - loss: 0.0473 - accuracy: 0.98 - ETA: 1s - loss: 0.0478 - accuracy: 0.98 - ETA: 1s - loss: 0.0490 - accuracy: 0.98 - ETA: 1s - loss: 0.0524 - accuracy: 0.98 - ETA: 1s - loss: 0.0537 - accuracy: 0.98 - ETA: 1s - loss: 0.0537 - accuracy: 0.98 - ETA: 1s - loss: 0.0528 - accuracy: 0.98 - ETA: 1s - loss: 0.0529 - accuracy: 0.98 - ETA: 1s - loss: 0.0524 - accuracy: 0.98 - ETA: 1s - loss: 0.0526 - accuracy: 0.98 - ETA: 1s - loss: 0.0535 - accuracy: 0.98 - ETA: 1s - loss: 0.0531 - accuracy: 0.98 - ETA: 1s - loss: 0.0522 - accuracy: 0.98 - ETA: 1s - loss: 0.0536 - accuracy: 0.98 - ETA: 1s - loss: 0.0542 - accuracy: 0.98 - ETA: 1s - loss: 0.0559 - accuracy: 0.98 - ETA: 0s - loss: 0.0555 - accuracy: 0.98 - ETA: 0s - loss: 0.0553 - accuracy: 0.98 - ETA: 0s - loss: 0.0551 - accuracy: 0.98 - ETA: 0s - loss: 0.0555 - accuracy: 0.98 - ETA: 0s - loss: 0.0554 - accuracy: 0.98 - ETA: 0s - loss: 0.0556 - accuracy: 0.98 - ETA: 0s - loss: 0.0556 - accuracy: 0.98 - ETA: 0s - loss: 0.0556 - accuracy: 0.98 - ETA: 0s - loss: 0.0549 - accuracy: 0.98 - ETA: 0s - loss: 0.0547 - accuracy: 0.98 - ETA: 0s - loss: 0.0540 - accuracy: 0.98 - ETA: 0s - loss: 0.0538 - accuracy: 0.98 - ETA: 0s - loss: 0.0542 - accuracy: 0.98 - ETA: 0s - loss: 0.0546 - accuracy: 0.98 - ETA: 0s - loss: 0.0549 - accuracy: 0.98 - ETA: 0s - loss: 0.0549 - accuracy: 0.98 - ETA: 0s - loss: 0.0550 - accuracy: 0.98 - ETA: 0s - loss: 0.0543 - accuracy: 0.98 - ETA: 0s - loss: 0.0539 - accuracy: 0.98 - ETA: 0s - loss: 0.0542 - accuracy: 0.98 - 2s 34us/sample - loss: 0.0541 - accuracy: 0.9835
# Epoch 4/5
# 60000/60000 [==============================] - ETA: 2s - loss: 0.0482 - accuracy: 0.98 - ETA: 2s - loss: 0.0371 - accuracy: 0.98 - ETA: 1s - loss: 0.0440 - accuracy: 0.98 - ETA: 1s - loss: 0.0425 - accuracy: 0.98 - ETA: 1s - loss: 0.0390 - accuracy: 0.98 - ETA: 1s - loss: 0.0398 - accuracy: 0.98 - ETA: 1s - loss: 0.0375 - accuracy: 0.98 - ETA: 1s - loss: 0.0359 - accuracy: 0.98 - ETA: 1s - loss: 0.0356 - accuracy: 0.98 - ETA: 1s - loss: 0.0394 - accuracy: 0.98 - ETA: 1s - loss: 0.0398 - accuracy: 0.98 - ETA: 1s - loss: 0.0390 - accuracy: 0.98 - ETA: 1s - loss: 0.0384 - accuracy: 0.98 - ETA: 1s - loss: 0.0406 - accuracy: 0.98 - ETA: 1s - loss: 0.0427 - accuracy: 0.98 - ETA: 1s - loss: 0.0424 - accuracy: 0.98 - ETA: 1s - loss: 0.0427 - accuracy: 0.98 - ETA: 1s - loss: 0.0451 - accuracy: 0.98 - ETA: 1s - loss: 0.0454 - accuracy: 0.98 - ETA: 1s - loss: 0.0455 - accuracy: 0.98 - ETA: 1s - loss: 0.0454 - accuracy: 0.98 - ETA: 0s - loss: 0.0455 - accuracy: 0.98 - ETA: 0s - loss: 0.0465 - accuracy: 0.98 - ETA: 0s - loss: 0.0469 - accuracy: 0.98 - ETA: 0s - loss: 0.0465 - accuracy: 0.98 - ETA: 0s - loss: 0.0473 - accuracy: 0.98 - ETA: 0s - loss: 0.0478 - accuracy: 0.98 - ETA: 0s - loss: 0.0485 - accuracy: 0.98 - ETA: 0s - loss: 0.0489 - accuracy: 0.98 - ETA: 0s - loss: 0.0492 - accuracy: 0.98 - ETA: 0s - loss: 0.0495 - accuracy: 0.98 - ETA: 0s - loss: 0.0496 - accuracy: 0.98 - ETA: 0s - loss: 0.0496 - accuracy: 0.98 - ETA: 0s - loss: 0.0502 - accuracy: 0.98 - ETA: 0s - loss: 0.0505 - accuracy: 0.98 - ETA: 0s - loss: 0.0508 - accuracy: 0.98 - ETA: 0s - loss: 0.0507 - accuracy: 0.98 - ETA: 0s - loss: 0.0516 - accuracy: 0.98 - ETA: 0s - loss: 0.0516 - accuracy: 0.98 - ETA: 0s - loss: 0.0518 - accuracy: 0.98 - ETA: 0s - loss: 0.0515 - accuracy: 0.98 - 2s 34us/sample - loss: 0.0511 - accuracy: 0.9849
# Epoch 5/5
# 60000/60000 [==============================] - ETA: 2s - loss: 0.0345 - accuracy: 0.98 - ETA: 1s - loss: 0.0261 - accuracy: 0.99 - ETA: 1s - loss: 0.0372 - accuracy: 0.99 - ETA: 1s - loss: 0.0398 - accuracy: 0.98 - ETA: 1s - loss: 0.0434 - accuracy: 0.98 - ETA: 1s - loss: 0.0431 - accuracy: 0.98 - ETA: 1s - loss: 0.0449 - accuracy: 0.98 - ETA: 1s - loss: 0.0458 - accuracy: 0.98 - ETA: 1s - loss: 0.0467 - accuracy: 0.98 - ETA: 1s - loss: 0.0477 - accuracy: 0.98 - ETA: 1s - loss: 0.0470 - accuracy: 0.98 - ETA: 1s - loss: 0.0466 - accuracy: 0.98 - ETA: 1s - loss: 0.0466 - accuracy: 0.98 - ETA: 1s - loss: 0.0476 - accuracy: 0.98 - ETA: 1s - loss: 0.0501 - accuracy: 0.98 - ETA: 1s - loss: 0.0500 - accuracy: 0.98 - ETA: 1s - loss: 0.0496 - accuracy: 0.98 - ETA: 1s - loss: 0.0505 - accuracy: 0.98 - ETA: 1s - loss: 0.0510 - accuracy: 0.98 - ETA: 1s - loss: 0.0498 - accuracy: 0.98 - ETA: 1s - loss: 0.0488 - accuracy: 0.98 - ETA: 0s - loss: 0.0483 - accuracy: 0.98 - ETA: 0s - loss: 0.0485 - accuracy: 0.98 - ETA: 0s - loss: 0.0492 - accuracy: 0.98 - ETA: 0s - loss: 0.0488 - accuracy: 0.98 - ETA: 0s - loss: 0.0480 - accuracy: 0.98 - ETA: 0s - loss: 0.0483 - accuracy: 0.98 - ETA: 0s - loss: 0.0477 - accuracy: 0.98 - ETA: 0s - loss: 0.0492 - accuracy: 0.98 - ETA: 0s - loss: 0.0494 - accuracy: 0.98 - ETA: 0s - loss: 0.0491 - accuracy: 0.98 - ETA: 0s - loss: 0.0492 - accuracy: 0.98 - ETA: 0s - loss: 0.0496 - accuracy: 0.98 - ETA: 0s - loss: 0.0497 - accuracy: 0.98 - ETA: 0s - loss: 0.0496 - accuracy: 0.98 - ETA: 0s - loss: 0.0504 - accuracy: 0.98 - ETA: 0s - loss: 0.0501 - accuracy: 0.98 - ETA: 0s - loss: 0.0500 - accuracy: 0.98 - ETA: 0s - loss: 0.0500 - accuracy: 0.98 - ETA: 0s - loss: 0.0510 - accuracy: 0.98 - ETA: 0s - loss: 0.0512 - accuracy: 0.98 - 2s 34us/sample - loss: 0.0512 - accuracy: 0.9856

# %% [markdown]
# Great! Now that we've trained the model, let's evaluate it on the test dataset using the [`evaluate`](https://www.tensorflow.org/api_docs/python/tf/keras/models/Sequential#evaluate) method:

# %%
'''TODO: Use the evaluate method to test the model!'''
test_loss, test_acc = cnn_model.evaluate(
    x=test_images, y=test_labels
)

print('Test accuracy:', test_acc)
# Out:
# 10000/10000 [==============================] - ETA: 24s - loss: 0.0458 - accuracy: 0.968 - ETA: 0s - loss: 0.0870 - accuracy: 0.972 - ETA: 0s - loss: 0.1040 - accuracy: 0.96 - ETA: 0s - loss: 0.0951 - accuracy: 0.97 - ETA: 0s - loss: 0.0916 - accuracy: 0.97 - ETA: 0s - loss: 0.0784 - accuracy: 0.97 - ETA: 0s - loss: 0.0728 - accuracy: 0.97 - ETA: 0s - loss: 0.0662 - accuracy: 0.98 - ETA: 0s - loss: 0.0604 - accuracy: 0.98 - 1s 54us/sample - loss: 0.0631 - accuracy: 0.9818
# Test accuracy: 0.9818

# %% [markdown]
# What is the highest accuracy you're able to achieve using the CNN model, and how does the accuracy of the CNN model compare to the accuracy of the simple fully connected network? What optimizers and learning rates seem to be optimal for training the CNN model?

# %%
print('Test accuracy:', test_acc)
# Out:
# Test accuracy: 0.9818

# %% [markdown]
# ### Make predictions with the CNN model
#
# With the model trained, we can use it to make predictions about some images. The [`predict`](https://www.tensorflow.org/api_docs/python/tf/keras/models/Sequential#predict) function call generates the output predictions given a set of input samples.

# %%
predictions = cnn_model.predict(test_images)

# %% [markdown]
# With this function call, the model has predicted the label for each image in the testing set. Let's take a look at the prediction for the first image in the test dataset:

# %%
predictions[0]
# Out:
# array([1.2197545e-15, 2.9500495e-09, 4.3495909e-09, 2.9580940e-10,
#        3.5339520e-10, 7.6116625e-15, 3.7846869e-21, 9.9999940e-01,
#        2.3567118e-10, 6.0608903e-07], dtype=float32)

# %% [markdown]
# As you can see, a prediction is an array of 10 numbers. Recall that the output of our model is a probability distribution over the 10 digit classes. Thus, these numbers describe the model's "confidence" that the image corresponds to each of the 10 different digits.
#
# Let's look at the digit that has the highest confidence for the first image in the test dataset:

# %%
'''TODO: identify the digit with the highest confidence prediction for the first
    image in the test dataset. '''
prediction = max(predictions[0])

print(prediction)
# Out:
# 0.9999994

# %% [markdown]
# So, the model is most confident that this image is a "???". We can check the test label (remember, this is the true identity of the digit) to see if this prediction is correct:

# %%
print("Label of this digit is:", test_labels[0])
plt.imshow(test_images[0,:,:,0], cmap=plt.cm.binary)
# Out:
# Label of this digit is: 7

# %% [markdown]
# It is! Let's visualize the classification results on the MNIST dataset. We will plot images from the test dataset along with their predicted label, as well as a histogram that provides the prediction probabilities for each of the digits:

# %%
#@title Change the slider to look at the model's predictions! { run: "auto" }

image_index = 79 #@param {type:"slider", min:0, max:100, step:1}
plt.subplot(1,2,1)
mdl.lab2.plot_image_prediction(image_index, predictions, test_labels, test_images)
plt.subplot(1,2,2)
mdl.lab2.plot_value_prediction(image_index, predictions,  test_labels)

# %% [markdown]
# We can also plot several images along with their predictions, where correct prediction labels are blue and incorrect prediction labels are red. The number gives the percent confidence (out of 100) for the predicted label. Note the model can be very confident in an incorrect prediction!

# %%
# Plots the first X test images, their predicted label, and the true label
# Color correct predictions in blue, incorrect predictions in red
num_rows = 5
num_cols = 4
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  mdl.lab2.plot_image_prediction(i, predictions, test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  mdl.lab2.plot_value_prediction(i, predictions, test_labels)

# %% [markdown]
# ## 1.4 Training the model 2.0
#
# Earlier in the lab, we used the [`fit`](https://www.tensorflow.org/api_docs/python/tf/keras/models/Sequential#fit) function call to train the model. This function is quite high-level and intuitive, which is really useful for simpler models. As you may be able to tell, this function abstracts away many details in the training call, and we have less control over training model, which could be useful in other contexts.
#
# As an alternative to this, we can use the [`tf.GradientTape`](https://www.tensorflow.org/api_docs/python/tf/GradientTape) class to record differentiation operations during training, and then call the [`tf.GradientTape.gradient`](https://www.tensorflow.org/api_docs/python/tf/GradientTape#gradient) function to actually compute the gradients. You may recall seeing this in Lab 1 Part 1, but let's take another look at this here.
#
# We'll use this framework to train our `cnn_model` using stochastic gradient descent.

# %%
# Rebuild the CNN model
cnn_model = build_cnn_model()

batch_size = 12
loss_history = mdl.util.LossHistory(smoothing_factor=0.95) # to record the evolution of the loss
plotter = mdl.util.PeriodicPlotter(sec=2, xlabel='Iterations', ylabel='Loss', scale='semilogy')
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3) # define our optimizer

if hasattr(tqdm, '_instances'): tqdm._instances.clear() # clear if it exists

for idx in tqdm(range(0, train_images.shape[0], batch_size)):
  # First grab a batch of training data and convert the input images to tensors
  (images, labels) = (train_images[idx:idx+batch_size], train_labels[idx:idx+batch_size])
  images = tf.convert_to_tensor(images, dtype=tf.float32)

  # GradientTape to record differentiation operations
  with tf.GradientTape() as tape:
    #'''TODO: feed the images into the model and obtain the predictions'''
    logits = cnn_model(images)

    #'''TODO: compute the categorical cross entropy loss
    loss_value = tf.keras.backend.sparse_categorical_crossentropy( labels, logits) # TODO

  loss_history.append(loss_value.numpy().mean()) # append the loss to the loss_history record
  plotter.plot(loss_history.get())

  # Backpropagation
  '''TODO: Use the tape to compute the gradient against all parameters in the CNN model.
      Use cnn_model.trainable_variables to access these parameters.''' 
  grads = tape.gradient( loss_value,cnn_model.trainable_variables )
  optimizer.apply_gradients(zip(grads, cnn_model.trainable_variables))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 5000/5000 [00:31<00:00, 158.39it/s]

# %% [markdown]
# ## 1.5 Conclusion
# In this part of the lab, you had the chance to play with different MNIST classifiers with different architectures (fully-connected layers only, CNN), and experiment with how different hyperparameters affect accuracy (learning rate, etc.). The next part of the lab explores another application of CNNs, facial detection, and some drawbacks of AI systems in real world applications, like issues of bias.

# %%
# Rebuild the CNN model
cnn_model = build_cnn_model()

batch_size = 12
loss_history = mdl.util.LossHistory(smoothing_factor=0.95) # to record the evolution of the loss
plotter = mdl.util.PeriodicPlotter(sec=2, xlabel='Iterations', ylabel='Loss', scale='semilogy')
optimizer = tf.keras.optimizers.SGD(learning_rate=1e-3) # define our optimizer

if hasattr(tqdm, '_instances'): tqdm._instances.clear() # clear if it exists

for idx in tqdm(range(0, train_images.shape[0], batch_size)):
  # First grab a batch of training data and convert the input images to tensors
  (images, labels) = (train_images[idx:idx+batch_size], train_labels[idx:idx+batch_size])
  images = tf.convert_to_tensor(images, dtype=tf.float32)

  # GradientTape to record differentiation operations
  with tf.GradientTape() as tape:
    #'''TODO: feed the images into the model and obtain the predictions'''
    logits = cnn_model(images)

    #'''TODO: compute the categorical cross entropy loss
    loss_value = tf.keras.backend.sparse_categorical_crossentropy( labels, logits) # TODO

  loss_history.append(loss_value.numpy().mean()) # append the loss to the loss_history record
  plotter.plot(loss_history.get())

  # Backpropagation
  '''TODO: Use the tape to compute the gradient against all parameters in the CNN model.
      Use cnn_model.trainable_variables to access these parameters.''' 
  grads = tape.gradient( loss_value,cnn_model.trainable_variables )
  optimizer.apply_gradients(zip(grads, cnn_model.trainable_variables))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 5000/5000 [00:28<00:00, 173.05it/s]
